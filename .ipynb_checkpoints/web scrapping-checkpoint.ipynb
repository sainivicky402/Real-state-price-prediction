# %%
import requests
from bs4 import BeautifulSoup


def gets_latest_python_articles():
    url="https://www.python.org/"
    response=requests.get(url)

    if response.status_code==200:
        soup=BeautifulSoup(response.text,"html.parser")
        latest_articles=[]

        for article in soup.select(".blog-widget li"):
            title=article.a.text.strip()
            latest_articles.append(title)
            
        return latest_articles
    
    else:
        print(f"fail to retrieve information.status code:{response.status_code}")
        return []
    
if __name__=="__main__":
    python_articles=gets_latest_python_articles()

    if python_articles:
        print("New News in the python.org section")
        for index,article in enumerate(python_articles,1):
            print(f"{index}, {article}")
        
    else:
        print('no articles found')
# Out:
# New News in the python.org section
# 1, EU’s Cyber Resilience Act Passes with Wins for Open Source
# 2, Python Software Foundation - December 2023 Newsletter
# 3, Announcing the Hidden Figures of Python Podcast!
# 4, Python 3.11.7 is now available
# 5, Python 3.12.1 is now available

# %%
pip install requests beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://facultytick.com/'

# %%
response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    links = soup.find_all('a')
    for link in links:
        print(link.get('href'))
else:
    print(f"failed to retrieve the page. status code: {response.status_code}")
# Out:
# https://facultytick.com/
# https://facultytick.com/category/engineering/
# https://facultytick.com/category/arts-science/
# https://facultytick.com/category/medical/
# https://facultytick.com/category/law/
# https://facultytick.com/category/polytechnic/
# https://facultytick.com/category/school/
# https://facultytick.com/category/school/junior-college/
# https://facultytick.com/category/research/
# https://facultytick.com/
# #
# https://facultytick.com/
# #
# https://facultytick.com/
# /privacy-policy/
# /about-us/
# /post-submission/
# /contact-us/
# #
# https://facultytick.com/
# https://facultytick.com/category/engineering/
# https://facultytick.com/2024/01/27/national-institute-of-technology-delhi-walk-in-interview-for-the-post-of-assistant-professor-purely-on-contractual-and-temporary-basis/
# https://facultytick.com/2024/01/27/national-institute-of-technology-delhi-walk-in-interview-for-the-post-of-assistant-professor-purely-on-contractual-and-temporary-basis/
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://quotes.toscrape.com"

# %%
response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    quotes = []
    for quotes in soup.find_all('div', class_ = "Quotes"):
        text = quote.find('span', class_='text').get_text(strip=True)
        author = quote.find('small', class_='author').get_text(strip=True)
        quotes.append({'text':text, 'author':author})
    for quote in quotes:
        print(f'Text:{quote["text"]}\nAuthor: {quote["author"]}\n-----')

else:
    print(f'failed to retrieve.status code: {response.status_code}')
